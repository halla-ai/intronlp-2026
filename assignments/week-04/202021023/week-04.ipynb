# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/halla-ai/intronlp-2026/blob/main/notebooks/week-04.ipynb)
#
# # 4주차 실습: 형태소 분석기로 품사 붙이기
#
# **목표.** 형태소 분석 라이브러리 eKoNLPy로 문장을 조각내고 품사를 붙인 뒤, 사람이 붙인 것과 다른 자리를 찾는다.

# %% [markdown]
# ## 0. 준비
#
# 형태소 분석 라이브러리 eKoNLPy와 이 노트북에서 표를 보여 줄 pandas를 설치합니다. 사전 파일을 함께 내려받기 때문에 처음에는 시간이 조금 걸립니다.
#
# 설치 셀에서 오류가 나면 다음 셀로 넘어가지 말고 오류의 마지막 줄을 확인하세요. 이미 설치한 뒤 런타임의 라이브러리를 바꾸었다면 **런타임을 다시 시작하고 이 노트북을 처음부터 다시 실행**하세요.

# %%
# 필요한 것 설치 (Colab에서 한 번만)
# %pip -q install "ekonlpy==2.2.1" "pandas>=1.5.3"

# %%
# 설치 확인: 이 셀에서 오류가 나면 아래 셀로 넘어가지 않습니다.
import sys
from importlib.metadata import version
import ekonlpy
import fugashi
import numpy
import scipy
import pandas

print("Python:", sys.version.split()[0])
print("eKoNLPy:", getattr(ekonlpy, "__version__", "알 수 없음"))
print("NumPy:", numpy.__version__)
print("SciPy:", scipy.__version__)
print("pandas:", pandas.__version__)
print("fugashi:", version("fugashi"))
# Out:
# Python: 3.12.13
# eKoNLPy: 2.2.1
# NumPy: 2.5.3
# SciPy: 1.18.1
# pandas: 3.0.6
# fugashi: 1.5.2

# %% [markdown]
# ## 1. 먼저 그냥 실행해 보기
#
# 아래 셀들을 위에서부터 차례로 실행하세요. 아무것도 고치지 않아도 끝까지 돌아갑니다.

# %% [markdown]
# ### 1-1. 분석기 불러오기
#
# 문장을 넣으면 `(조각, 태그)` 짝의 목록이 나옵니다.

# %%
from ekonlpy.tag import Mecab

tagger = Mecab()
print(tagger.pos("나는 성산으로 갔다"))
# Out:
# [('나', 'NP'), ('는', 'JX'), ('성산', 'NNG'), ('으로', 'JKB'), ('갔', 'VV'), ('다', 'EC')]

# %% [markdown]
# ### 1-2. 태그 대응표
#
# 분석기의 태그는 `NNG`, `JKB` 같은 낯선 약자이고 수업에서 쓴 여섯 가지보다 훨씬 잘게 나뉘어 있습니다. 외울 필요는 없습니다. 아래 `show` 가 약자 옆에 풀이와 수업 태그를 붙여 줍니다.
#
# | 분석기 태그 | 수업 태그 |
# |---|---|
# | NNG, NNP, NNB, NP, NR 등 N으로 시작 | 명사 |
# | J로 시작 (JKS, JKO, JKB, JX 등) | 조사 |
# | VV, VX, XSV (물질**하**는의 하) | 동사 |
# | VA, XSA (신기**했**다의 했) | 형용사 |
# | MAG, MAJ | 부사 |
# | E로 시작 (EP, EC, EF, ETM 등) | 어미 |
# | 그 밖 (MM, XR, 기호 등) | 기타 |

# %%
import pandas as pd

def course_tag(tag):
    tag = tag.split("+")[0]
    if tag.startswith("N"):
        return "명사"
    if tag.startswith("J"):
        return "조사"
    if tag in ("VV", "VX", "XSV"):
        return "동사"
    if tag in ("VA", "XSA"):
        return "형용사"
    if tag in ("MAG", "MAJ"):
        return "부사"
    if tag.startswith("E"):
        return "어미"
    return "기타"

def show(sentence):
    rows = [(piece, tag, tagger.tagset.get(tag.split("+")[0], ""), course_tag(tag))
            for piece, tag in tagger.pos(sentence)]
    print(sentence, "->", len(rows), "조각")
    return pd.DataFrame(rows, columns=["조각", "태그", "풀이", "수업 태그"])

show("나는 성산으로 갔다")
# Out:
# 나는 성산으로 갔다 -> 6 조각
#    조각   태그      풀이 수업 태그
# 0   나   NP     대명사    명사
# 1   는   JX     보조사    조사
# 2  성산  NNG   일반 명사    명사
# 3  으로  JKB  부사격 조사    조사
# 4   갔   VV      동사    동사
# 5   다   EC   연결 어미    어미

# %% [markdown]
# ### 1-3. 지정 문장 1: 사람이 붙인 것과 나란히
#
# 사람은 `새별오름에서 쇠소깍까지 갔다` 를 여섯 조각으로 봅니다. 분석기 출력과 조각 경계부터 맞는지 봅니다. **조각 경계가 어긋나면 그 뒤의 이름표는 비교할 수조차 없습니다.**

# %%
sentence = "새별오름에서 쇠소깍까지 갔다"
human = ["새별오름/명사", "에서/조사", "쇠소깍/명사", "까지/조사", "가/동사", "았다/어미"]
analyzer = [f"{p}/{course_tag(t)}" for p, t in tagger.pos(sentence)]

print("사람  ", len(human), "조각:", " · ".join(human))
print("분석기", len(analyzer), "조각:", " · ".join(analyzer))
# Out:
# 사람   6 조각: 새별오름/명사 · 에서/조사 · 쇠소깍/명사 · 까지/조사 · 가/동사 · 았다/어미
# 분석기 7 조각: 새별/명사 · 오름/명사 · 에서/조사 · 쇠소깍/명사 · 까지/조사 · 갔/동사 · 다/어미

# %% [markdown]
# ### 1-4. 지정 문장 2, 3
#
# - `성산일출봉 앞에서 물질하는 걸 보난 신기했다`: 성산일출봉이 통째로 잡히는지, 보난(보니까)이 어떻게 잘리는지, 걸이 "것"과 "을"로 나뉘는지 봅니다
# - `혼저 옵서예`: 사전에 없는 방언이 어떻게 처리되는지 봅니다

# %%
show("성산일출봉 앞에서 물질하는 걸 보난 신기했다")
# Out:
# 성산일출봉 앞에서 물질하는 걸 보난 신기했다 -> 13 조각
#      조각   태그          풀이 수업 태그
# 0    성산  NNP       고유 명사    명사
# 1   일출봉  NNP       고유 명사    명사
# 2     앞  NNG       일반 명사    명사
# 3    에서  JKB      부사격 조사    조사
# 4    물질  NNG       일반 명사    명사
# 5     하  XSV   동사 파생 접미사    동사
# 6     는  ETM   관형형 전성 어미    어미
# 7     걸  NNB       의존 명사    명사
# 8     보   VV          동사    동사
# 9     난   EC       연결 어미    어미
# 10   신기  NNG       일반 명사    명사
# 11    했  XSA  형용사 파생 접미사   형용사
# 12    다   EC       연결 어미    어미

# %%
show("혼저 옵서예")
# Out:
# 혼저 옵서예 -> 5 조각
#   조각   태그     풀이 수업 태그
# 0  혼  NNG  일반 명사    명사
# 1  저   VV     동사    동사
# 2  옵   EP  선어말어미    어미
# 3  서   EC  연결 어미    어미
# 4  예  NNG  일반 명사    명사

# %% [markdown]
# 다른 자리를 찾으면 오류 유형 코드를 붙입니다.
#
# | 코드 | 유형 |
# |---|---|
# | 가 | 고유명사 쪼개짐 |
# | 나 | 고유명사를 일반명사로 |
# | 다 | 사전에 없는 말을 아는 조각으로 억지로 맞춤 |
# | 라 | 조사 잘못 나눔 |
# | 마 | 품사 헷갈림 |

# %% [markdown]
# ## 2. 한 지점만 바꿔 보기
#
# 아래 셀의 `TODO` 로 표시된 **한 곳만** 바꾸고 다시 실행하세요.
#
# > 바꾸기 전 결과를 먼저 확인해 두면 무엇이 달라졌는지 비교할 수 있습니다.

# %% [markdown]
# 따옴표 안에 내 문장을 넣습니다. 온라인 활동 A의 `하늘을 나는 새가 아주 빠르다`, `비가 와서 한라산에 못 갔다` 나 방언 문장 `폭삭 속았수다` 를 넣어 보세요.

# %%
# TODO: 따옴표 안의 문장을 바꿔 보세요
sentence = "폭삭 속았수다"

# 아래는 그대로 둡니다
show(sentence)
# Out:
# 폭삭 속았수다 -> 4 조각
#    조각   태그     풀이 수업 태그
# 0  폭삭  MAG  일반 부사    부사
# 1   속   VV     동사    동사
# 2   았   EP  선어말어미    어미
# 3  수다   EC  연결 어미    어미

# %% [markdown]
# ## 3. 확인 질문
#
# 1. 지정 문장 세 개의 출력을 옮기고, 사람이 붙인 것과 다른 자리에 표시하세요.
# 2. 다른 자리마다 오류 유형 코드(가~마)를 붙이세요.
# 3. 흔한 말과 드문 말(지명, 방언) 중 어느 쪽에서 더 많이 어긋났나요? 왜 그렇다고 생각하나요?
#
# 답은 아래 셀에 글로 적으면 됩니다. 코드가 아니어도 됩니다.

# %% [markdown]
# **답**
#
# 1. 지정 문장 세 개의 출력과 사람이 붙인 것과 다른 자리
#    - `새별오름에서 쇠소깍까지 갔다` → 새별/명사 · 오름/명사 · 에서/조사 · 쇠소깍/명사 · 까지/조사 · 갔/동사 · 다/어미 (7조각). 다른 자리: **새별오름**을 새별/오름으로 쪼갬. 갔/다는 가/았다와 경계만 다르고 품사는 같음.
#    - `성산일출봉 앞에서 물질하는 걸 보난 신기했다` → 성산/일출봉/앞/에서/물질/하/는/걸/보/난/신기/했/다 (13조각). 다른 자리: **성산일출봉**을 성산/일출봉으로 쪼갬, **걸**을 것+을로 나누지 않고 의존명사 하나로, 방언 **보난**(보니까)을 보(동사)/난(어미)로 맞춤.
#    - `혼저 옵서예` → 혼/명사 · 저/동사 · 옵/어미 · 서/어미 · 예/명사 (5조각). 인사말 전체가 사전에 없어 엉뚱하게 잘림.
# 2. 오류 유형 코드
#    - 새별오름 → 새별/오름: 가
#    - 성산일출봉 → 성산/일출봉: 가
#    - 걸 → 조사 안 나눔: 라
#    - 보난 → 보/난: 다
#    - 혼저 옵서예 전체: 다
#    - (TODO) 폭삭 속았수다 → 폭삭/속/았/수다, "속았수다"를 "속다"로 봄: 다
# 3. 드문 말(지명, 방언) 쪽에서 더 많이 어긋났다. 흔한 말(앞에서, 갔다, 신기했다)은 다 맞았는데, 지명과 방언은 분석기 사전에 없어서 아는 조각으로 억지로 쪼개기 때문이다.

# %% [markdown]
# ## 4. 제출
#
# 1. 상단 메뉴 **파일 > .ipynb 다운로드** 로 이 노트북을 내려받습니다
# 2. [저장소](https://github.com/halla-ai/intronlp-2026)의 `assignments/week-04/<내 학번>/` 에 업로드합니다
# 3. Pull Request를 엽니다
#
# 자세한 방법은 강의 사이트의 **과제 제출** 문서에 있습니다.
#
# ---
#
# **막혔나요?** 오류 메시지의 마지막 줄을 먼저 읽어 보세요. 그래도 안 되면 AI Professor 튜터에게 묻고, 그래도 막히면 저장소 Issues에 남기세요.
